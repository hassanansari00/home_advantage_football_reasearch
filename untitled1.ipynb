# %% [markdown]
# <a href="https://colab.research.google.com/github/hassanansari00/home_advantage_football_reasearch/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('PL 2023-24.csv')

columns_we_need=[
    'Date','FTHG','FTAG',
    'FTR','HS', 'AS','HST','AST','HF',
    'AF','HY','AY'
]

clean_df = df[columns_we_need].copy()

clean_df = clean_df.rename(columns={
    'FTHG': 'Home_Goals',
    'FTAG': 'Away_Goals',
    'FTR':  'Match_Result',
    'HS':   'Home_Shots',
    'AS':   'Away_Shots',
    'HST':  'Home_Shots_Target',
    'AST':  'Away_Shots_Target',
    'HF':   'Home_Fouls',
    'AF':   'Away_Fouls',
    'HY':   'Home_Yellows',
    'AY':   'Away_Yellows'
})
clean_df.head()
# Out:
#         Date  Home_Goals  Away_Goals Match_Result  Home_Shots  Away_Shots  \
# 0 2023-08-11           0           3            A           6          17
# 1 2023-08-12           2           1            H          15           6
# 2 2023-08-12           1           1            D          14          16
# 3 2023-08-12           4           1            H          27           9
# 4 2023-08-12           0           1            A          19           9
#
#    Home_Shots_Target  Away_Shots_Target  Home_Fouls  Away_Fouls  Home_Yellows  \
# 0                  1                  8          11           8             0
# 1                  7                  2          12          12             2
# 2                  5                  3           9          14             1
# 3                 12                  3          11          12             2
# 4                  9                  2          12           6             0
#
#    Away_Yellows
# 0             0
# 1             2
# 2             4
# 3             2
# 4             2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. THE MATH: Calculating the Averages ---
# We use the .mean() function to find the average per match over the whole season
home_goals_avg = clean_df['Home_Goals'].mean()
away_goals_avg = clean_df['Away_Goals'].mean()

home_shots_avg = clean_df['Home_Shots_Target'].mean()
away_shots_avg = clean_df['Away_Shots_Target'].mean()

home_yellows_avg = clean_df['Home_Yellows'].mean()
away_yellows_avg = clean_df['Away_Yellows'].mean()

# Print the results so we can see the exact numbers
print("--- QUICK INSIGHTS ---")
print(f"Goals per match:  Home = {home_goals_avg:.2f} | Away = {away_goals_avg:.2f}")
print(f"Shots on target:  Home = {home_shots_avg:.2f} | Away = {away_shots_avg:.2f}")
print(f"Yellow cards:     Home = {home_yellows_avg:.2f} | Away = {away_yellows_avg:.2f}")

# --- 2. THE VISUAL: Creating a Professional Chart ---

sns.set_theme(style="whitegrid") # Makes the chart look modern and clean
plt.figure(figsize=(8, 5))

# Create the Bar Chart
metrics = ['Home Goals', 'Away Goals']
averages = [home_goals_avg, away_goals_avg]

sns.barplot(x=metrics, y=averages, palette='viridis')

# Add titles and labels
plt.title('The Home Advantage: Average Goals Scored (Premier League 23/24)', fontsize=14, fontweight='bold')
plt.ylabel('Average Goals per Match', fontsize=12)

# Show the chart
plt.show()
# Out:
# --- QUICK INSIGHTS ---
# Goals per match:  Home = 1.80 | Away = 1.48
# Shots on target:  Home = 5.44 | Away = 4.43
# Yellow cards:     Home = 1.91 | Away = 2.26
# /tmp/ipykernel_1046/2363333584.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=metrics, y=averages, palette='viridis')

# %%
df.head()
